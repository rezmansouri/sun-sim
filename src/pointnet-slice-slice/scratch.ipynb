# %%
from utils import PointDataset
from static_model import PointNetModel
import matplotlib.pyplot as plt

# %%
dataset = PointDataset(
    [
        '/Users/reza/Career/DMLab/SURROGATE/Data/psi_web_sample/cr1732/kpo_mas_mas_std_0101',
        '/Users/reza/Career/DMLab/SURROGATE/Data/psi_web_sample/cr1733/kpo_mas_mas_std_0101'
    ]
)

# %%
x, y = dataset[0]
# Out:
# (14080,) (14080,) (14080,) (14080,)

# %%
print(x.shape)
# Out:
# torch.Size([4, 14080])

# %%
y.shape
# Out:
# torch.Size([14080, 1])

# %%
model = PointNetModel()

# %%
yhat = model(x.unsqueeze(0))

# %%
yhat.shape
# Out:
# torch.Size([1, 14080, 1])

# %%
y = y.reshape((128, 110))

# %%
plt.imshow(y, cmap='jet_r')

# %%
x = x[-1, :].reshape((128, 110))
plt.imshow(x, cmap='jet_r')
