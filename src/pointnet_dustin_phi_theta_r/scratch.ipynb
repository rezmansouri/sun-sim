# %%
from utils import PointDataset
from static_model import PointNetModel
import matplotlib.pyplot as plt

# %%
dataset = PointDataset(
    [
        '/Users/reza/Career/DMLab/SURROGATE/Data/psi_web_sample/cr1732/kpo_mas_mas_std_0101',
        '/Users/reza/Career/DMLab/SURROGATE/Data/psi_web_sample/cr1733/kpo_mas_mas_std_0101'
    ]
)

# %%
x, y = dataset[0]

# %%
x[1, 2, 3]
# Out:
# tensor(0.0143)

# %%
print(x.shape)
# Out:
# torch.Size([140, 4, 14080])

# %%
y.shape
# Out:
# torch.Size([140, 14080, 1])

# %%
model = PointNetModel()

# %%
yhat = model(x[0].unsqueeze(0))
# Out:
# torch.Size([1, 1024]) torch.Size([1, 64, 14080])

# %%
yhat.shape
# Out:
# torch.Size([1, 14080, 1])

# %%
128 * 110
# Out:
# 14080

# %%
yy = y[100].reshape((128, 110))

# %%
plt.imshow(yy, cmap='jet_r')

# %%
xx = x[120, -1, :].reshape((128, 110))
plt.imshow(xx, cmap='jet_r')
