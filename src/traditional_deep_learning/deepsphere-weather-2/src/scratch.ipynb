# %%
import torch
from architectures import UNetSpherical
from pygsp.graphs import SphereHealpix

# %%
model = UNetSpherical(32, 2, 1, knn=20)
# Out:
# 32
# 32
# 32
# 32
# 16
# 16
# 8
# 8

# %%
model(torch.randn(1, 128 * 96, 2)).shape
# Out:
# torch.Size([1, 12288, 1])

# %%
from utils import SphericalDataset
import matplotlib.pyplot as plt

# %%
dataset = SphericalDataset(['/Users/reza/Career/DMLab/SURROGATE/Data/psi_web_sample/train/cr1732/kpo_mas_mas_std_0101'])

# %%
cube = dataset[0]

# %%
cube.shape
# Out:
# torch.Size([141, 12288, 1])

# %%
plt.imshow(cube[0, :, :].reshape(96, 128))

# %%
torch.min(cube), torch.max(cube)
# Out:
# (tensor(0.), tensor(1.))
