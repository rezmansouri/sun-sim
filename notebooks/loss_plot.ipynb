# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train_loss = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/deeponet/exp_16/train_loss.npy')
val_loss = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/deeponet/exp_16/val_loss.npy')

# %%
# Create the plot
plt.figure(figsize=(20, 10))
epochs = np.arange(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, label="Training Loss", marker='o')
plt.plot(epochs, val_loss, label="Validation Loss", marker='s')

# Add labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(20, 10))
epochs = np.arange(1, len(train_loss) + 1)

plt.plot(epochs, np.log(train_loss), label="Training Loss", marker='o')
plt.plot(epochs, np.log(val_loss), label="Validation Loss", marker='s')

# Add labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Log Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
e3_val = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/pointnet-slice-slice/exp_3/val_loss.npy')
print(e3_val.min())
# Out:
# 0.006750710657797754

# %%
e4_val = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/pointnet-slice-slice/exp_4/val_loss.npy')
print(e4_val.min())
# Out:
# 0.0063938933599274606

# %%
e5_val = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/pointnet-slice-slice/exp_5/val_loss.npy')
print(e5_val.min())
# Out:
# 0.006678096775431186

# %%
e6_val = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/pointnet-slice-slice/exp_6/val_loss.npy')
print(e6_val.min())
# Out:
# 0.006029917683918029

# %%
e7_val = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/pointnet-sequential-slices/exp_7/val_loss.npy')
print(e7_val.min())
# Out:
# 0.32011255621910095

# %%
e8_val = np.load('/Users/reza/Career/DMLab/SURROGATE/results/laplace/pointunet-slice-slice/exp_8/val_loss.npy')
print(e8_val.min())
# Out:
# 0.00547153182560578
